# %% [markdown]
# <a href="https://colab.research.google.com/github/archeeetah/Colour-Detection-In-images-AIML/blob/main/Colour_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
img=cv2.imread('/content/Colours image.jpeg')
plt.figure(figsize=(20,8))
plt.imshow(img)

grid_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,8))
plt.imshow(grid_RGB)

grid_HSV = cv2.cvtColor(grid_RGB,cv2.COLOR_RGB2HSV)
lower = np.array([150,150,50])
upper = np.array([150,255,255])
mask = cv2.inRange(grid_HSV,lower,upper)
plt.imshow(mask)
res = cv2.bitwise_and(grid_RGB, grid_RGB ,mask=mask)
plt.imshow(res)
